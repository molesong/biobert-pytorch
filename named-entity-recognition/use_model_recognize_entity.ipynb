# %% [markdown]
# ## Extract entities label from biobert model output.

# %%
import os
import torch
from transformers import AutoConfig, AutoTokenizer, AutoModelForTokenClassification
from collections import defaultdict
import numpy as np
import re 
def load_model_and_tokenizer(model_dir, device):
    # 加载配置文件、分词器和模型
    config = AutoConfig.from_pretrained(model_dir)
    tokenizer = AutoTokenizer.from_pretrained(model_dir)
    model = AutoModelForTokenClassification.from_pretrained(model_dir)
    
    #add tokenizer
    new_tokens = ['COVID', 'hospitalization','LacCer','Phosphatidylcholine','S1P d18:1']
    num_added_toks = tokenizer.add_tokens(new_tokens)
    model.resize_token_embeddings(len(tokenizer))

    model.to(device)
    model.eval()

    return config, tokenizer, model

def predict(text, tokenizer, model, label_map, device):
    # 将输入文本分词
    text_split = text.split()
    # text_split = re.findall(r'\b\w+\s*\([^)]*\)|\b\w+', text)
    inputs = tokenizer(text_split, return_tensors="pt", truncation=True, is_split_into_words=True, max_length=512, add_special_tokens=False)
    input_ids = inputs["input_ids"].to(device)
    attention_mask = inputs["attention_mask"].to(device)

    # 使用模型进行预测
    with torch.no_grad():
        outputs = model(input_ids, attention_mask=attention_mask)
        
        # 兼容不同版本的transformers库
        if isinstance(outputs, tuple):
            logits = outputs[0]
        else:
            logits = outputs.logits

    # 获取预测结果
    predictions = logits[0].cpu().detach().numpy()

    # 将预测结果转换为标签
    label_probability = defaultdict(float)
    for idx, word_index in enumerate(inputs.word_ids()):
        label_probability[word_index] += predictions[idx]
    label_probability = np.array(list(label_probability.values()))
    text_label_predictions = np.argmax(label_probability, axis=1)

    return text_split,text_label_predictions


# def predict(text, tokenizer, model, label_map, device='cpu'):
#     # 将输入文本分词
#     text_split = text.split()
#     inputs = tokenizer(text_split, return_tensors="pt", truncation=True, is_split_into_words=True, max_length=512)
#     input_ids = inputs["input_ids"].to(device)
#     attention_mask = inputs["attention_mask"].to(device)

#     # 使用模型进行预测
#     with torch.no_grad():
#         outputs = model(input_ids, attention_mask=attention_mask)
        
#         # 兼容不同版本的transformers库
#         if isinstance(outputs, tuple):
#             logits = outputs[0]
#         else:
#             logits = outputs.logits

#     # 获取预测结果
#     predictions = torch.argmax(logits, dim=2)
    
#     predictions = predictions.cpu().detach().numpy()  # 将GPU中的tensor移至CPU以便转换为numpy数组

#     # 将预测结果映射回标签
#     token_predictions = [label_map[pred] for pred in predictions[0]]
#     word_predictions = []   

#     # 将预测结果重新组合成原始单词形式
#     print('text_split length:     ' + str(len(text_split)))
#     print('tokens_predictions length:' + str(len(token_predictions)))
    
#     for word, prediction in zip(text_split, token_predictions):  #这种方式应该是不行的。
#         word_predictions.append((word, prediction))

#     return word_predictions

# model_dir = "/home/data/t200404/bioinfo/P_subject/NLP/biobert/biobertModelWarehouse/model_from_trained/NER/4_combine_lipid_disease_ture_combine_3.3_data_from_MetaboliteNER_replace"  # 替换为你模型的保存路径
# model_dir = "/home/data/t200404/bioinfo/P_subject/NLP/biobert/biobertModelWarehouse/model_from_trained/NER/4_combine_lipid_disease_ture_combine_3"  # 替换为你模型的保存路径
model_name = '1_LipidCorpus'
model_dir = "/home/data/t200404/bioinfo/P_subject/NLP/biobert/biobertModelWarehouse/model_from_trained/NER_add_words_change_split_way/" + model_name
model_name = '4_combine_lipid_disease_ture_combine_3'
model_dir = "/home/data/t200404/bioinfo/P_subject/NLP/biobert/biobertModelWarehouse/model_from_trained/NER/" + model_name


config, tokenizer, model = load_model_and_tokenizer(model_dir,device = 'cuda')
label_map = config.id2label
# text = '''This severe pulmonary defect in Pla2g5-Tg mice was attributable to marked reduction of the lung surfactant phospholipids, phosphatidylcholine (PC) (Figure 1a) and phosphatidylglycerol (PG) (Figure 1b), as demonstrated by ESI-MS (electrospray ionization mass spectrometry) analysis.'''
# text = 'Thus, changes in plasma PC (16:0) levels, plasma S1P d18:1 levels, plasma MonCer d18:1 levels or plasma LacCer d18:1 levels were inferred to be disease-induced changes in AD or DLB'
# prediction = predict(text, tokenizer, model, label_map,device = 'cuda')
# print(prediction)
# Out:
# You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embeding dimension will be 29001. This might induce some performance reduction as *Tensor Cores* will not be available. For more details  about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc

# %%
text = 'Thus, changes in plasma PC (16:0/18:2) levels, Cer d18:2/21:0， Phosphatidylcholine (22:4w6/22:0)'
# text = 'Additionally we searched for a between SL metabolites and key AERD biomarkers, FA 20:4;15OH (15-HETE), human leukcyte antigen HLA-DBP1*0301'
# text = 'In contrast, ceramide (Cer) Cer 18:1;O2/21:0 and Cer 18:2;O2/23:0, ursodeoxycholic acid (UDCA), and the ratios BCAA to ArAA, and BCAA to tyrosine (BTR) decreased along with the fibrosis stages of the studied patients (absolute PCC'
# text = 'The MS/MS spectrum of PC(17:0/17:0) is shown in the,which showed'
# text = 'This severe pulmonary defect in Pla2g5-Tg mice was attributable to marked reduction of the lung surfactant phospholipids, phosphatidylcholine (PC) (Figure 1a) and phosphatidylglycerol (PG) (Figure 1b), as demonstrated by ESI-MS (electrospray ionization mass spectrometry) analysis.'
prediction = predict(text, tokenizer, model, label_map,device = 'cuda')
for (word, label) in zip(prediction[0],prediction[1]):
    print(word, label_map[label])
# print(prediction)
# Out:
# Thus, O
# changes O
# in O
# plasma O
# PC B-lipid
# (16:0/18:2) O
# levels, O
# Cer B-lipid
# d18:2/21:0， O
# Phosphatidylcholine O
# (22:4w6/22:0) O

# %%
label_map
# Out:
# {0: 'B-disease', 1: 'I-disease', 2: 'B-lipid', 3: 'I-lipid', 4: 'O'}

# %%
len(tokenizer)
# Out:
# 29230

# %%
import re

sentence = "Hello world (do not split this part) and keep (this together too)"
# 使用正则表达式匹配：普通单词，或者包含括号的部分和前面的单词
parts = re.findall(r'\b\w+\s*\([^)]*\)|\b\w+', sentence)

print(parts)

# %%
model_dir = "/home/data/t200404/bioinfo/P_subject/NLP/biobert/biobertModelWarehouse/model_from_trained/NER/4_combine_lipid_disease_ture_combine_3"
config = AutoConfig.from_pretrained(model_dir)
tokenizer = AutoTokenizer.from_pretrained(model_dir)
model = AutoModelForTokenClassification.from_pretrained(model_dir)
new_tokens = ['COVID', 'hospitalization','Cer','Phosphatidylcholine']
num_added_toks = tokenizer.add_tokens(new_tokens)
model.resize_token_embeddings(len(tokenizer))
model.to('cpu')
model.eval()

# %%
from transformers import BertForMaskedLM, BertTokenizer
tokenizer = BertTokenizer.from_pretrained(model_dir, use_fast=True)
model = BertForMaskedLM.from_pretrained(model_dir)
# Out:
# Some weights of BertForMaskedLM were not initialized from the model checkpoint at /home/data/t200404/bioinfo/P_subject/NLP/biobert/biobertModelWarehouse/model_from_trained/NER/4_combine_lipid_disease_ture_combine_3_add_words_test and are newly initialized: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
vocab_size = tokenizer.vocab_size
vocab_size
# print(f"词表大小：{vocab_size}")
# print(f"最大索引：{input_ids.max().item()}")
# if input_ids.max().item() >= vocab_size:
#     print("输入中存在超出词表范围的索引。")
# Out:
# 28996

# %%
#for test, first version.
import os
import torch
from transformers import AutoConfig, AutoTokenizer, AutoModelForTokenClassification

def load_model_and_tokenizer(model_dir,device):
    # 加载配置文件、分词器和模型
    config = AutoConfig.from_pretrained(model_dir)
    tokenizer = AutoTokenizer.from_pretrained(model_dir)
    model = AutoModelForTokenClassification.from_pretrained(model_dir)
    
    model.to(device)
    model.eval()

    return config, tokenizer, model

def predict(text, tokenizer, model, label_map, device):
    # 将输入文本分词
    text_split = text.split()
    inputs = tokenizer(text_split, return_tensors="pt", truncation=True, is_split_into_words=True, max_length=512, add_special_tokens=False)
    input_ids = inputs["input_ids"].to(device)
    attention_mask = inputs["attention_mask"].to(device)

    # 使用模型进行预测
    with torch.no_grad():
        outputs = model(input_ids, attention_mask=attention_mask)
        
        # 兼容不同版本的transformers库
        if isinstance(outputs, tuple):
            logits = outputs[0]
        else:
            logits = outputs.logits

    # 获取预测结果
    predictions = torch.argmax(logits, dim=2)
    
    predictions = predictions.cpu().detach().numpy()  #gpu中的torch.tensor,需要先把它放进cpu才可以转化
    

    # 将预测结果转换为标签
    # example = "This is a tokenization example"
    txt_label_index_list = []
    #BatchEncoding.word_ids returns a list mapping words to tokens
    for w_idx in set(inputs.word_ids()):
        start, _ = inputs.word_to_tokens(w_idx)  #BatchEncoding.word_to_tokens tells us which and how many tokens are used for the specific word
        txt_label_index_list.append(start)         # we add +1 because you wanted to start with 1 and not with 0
    txt_predictions  = [predictions[0][index] for index in txt_label_index_list]
    return text_split,txt_predictions


model_name = "4_combine_lipid_disease_ture_combine_3.3_data_from_MetaboliteNER_replace"
# model_name = "4_combine_lipid_disease_ture_combine_3"
model_dir = "/home/data/t200404/bioinfo/P_subject/NLP/biobert/biobertModelWarehouse/model_from_trained/NER/" + model_name  # 替换为你模型的保存路径
config, tokenizer, model = load_model_and_tokenizer(model_dir,device="cuda")
label_map = config.id2label

# %%
#for test
text = ['''Thus, changes in plasma S1P d16:1 levels, plasma S1P d18:1 levels, plasma MonCer d18:1 levels or plasma LacCer d18:1 levels were inferred to be disease-induced changes in Alzheimer's disease or DLB''']
for sentence in text:
    prediction = predict(sentence, tokenizer, model, label_map, device = 'cuda') 

for word, number in zip(prediction[0], prediction[1]):
    print(word, number)
# Out:
# Thus, 4
# changes 4
# in 4
# plasma 4
# S1P 4
# d16:1 4
# levels, 4
# plasma 4
# Ceremide(d18:1) 4
# levels, 4
# plasma 4
# MonCer 4
# d18:1 4
# levels 4
# or 4
# plasma 4
# LacCer 4
# d18:1 4
# levels 4
# were 4
# inferred 4
# to 4
# be 4
# disease-induced 4
# changes 4
# in 4
# Alzheimer's 4
# disease 4
# or 4
# DLB 4

# %%
for (token, label) in zip(prediction[0]['tokens'][1:],prediction[0]['labels'][1:]):
    print(token, label)

# %%
import pickle
path_ = '/home/data/t200404/bioinfo/P_subject/NLP/biobert/datasets/for_recognize/download_paper_and_use_Auto-CORPus_deal_paper/deal/extract_result/'
with open(path_ + 'df_dict_only_lipid.pkl','rb') as f:
    df_dict_only_lipid = pickle.load(f)
PMC_bioc_name = 'PMC9481132_bioc.json'

df_dict_only_lipid[PMC_bioc_name]['predictions_lipid_'] = df_dict_only_lipid[PMC_bioc_name]['sentence'].apply(
    lambda x: predict(x, tokenizer, model, label_map)
)

# %%
import pickle
with open('df_dict_lipid_and_disease_4_combine_lipid_disease_ture_combine_2.pkl','rb') as f:
    df_dict_only_lipid = pickle.load(f)
# PMC_bioc_name = 'PMC9529825_bioc.json'
# df_dict_only_lipid[PMC_bioc_name].head()

# %%
aa = list(df_dict_only_lipid.keys())
aa[3]
# Out:
# 'PMC8917834_bioc.json'

# %%
PMC_bioc_name = aa[5]
df_dict_only_lipid[PMC_bioc_name].head()
# df_dict_only_lipid[PMC_bioc_name].iloc[2]['predictions_lipid']
# df_dict_only_lipid[PMC_bioc_name].iloc[2]['sentence']

# %%
with open('df_dict_lipid_and_disease_4_combine_lipid_disease_ture_combine_2.pkl','rb') as f:
    df_dict_only_lipid = pickle.load(f)

# %%
a = list(df_dict_only_lipid.keys())
a.index('PMC9499334_bioc.json')
# Out:
# 378

# %%
keys_name = a[800]
df_dict_only_lipid[keys_name]
# df_dict_only_lipid[keys_name].iloc[5]['predictions_disease']

# %%
# import pickle
# with open('df_dict.pkl','rb') as f:
#     df_dict = pickle.load(f)

for pmc_ in df_dict.keys():
    df = df_dict[pmc_]
    list_ = list(set(df['predictions']))
    if len(list_) > 1:
        print(list_)
    # print(df.head())
    # break

# %%
sentence = '''
Thus, changes in plasma S1P d16:1 levels, plasma S1P d18:1 levels, plasma MonCer d18:1 levels or plasma LacCer d18:1 levels were inferred to be disease-induced changes in Alzheimer's disease or DLB
'''
prediction = predict(sentence, tokenizer, model, label_map)
print(list(set(prediction['labels'])))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 4
#       1 sentence = '''
#       2 Thus, changes in plasma S1P d16:1 levels, plasma S1P d18:1 levels, plasma MonCer d18:1 levels or plasma LacCer d18:1 levels were inferred to be disease-induced changes in Alzheimer's disease or DLB
#       3 '''
# ----> 4 prediction = predict(sentence, tokenizer, model, label_map)
#       5 print(list(set(prediction['labels'])))
#
# TypeError: predict() missing 1 required positional argument: 'device'

# %% [markdown]
# ## The tokens score is be used for output.

# %%
#for test, first version.
import os
import torch
from transformers import AutoConfig, AutoTokenizer, AutoModelForTokenClassification

def load_model_and_tokenizer(model_dir,device = 'cuda'):
    # 加载配置文件、分词器和模型
    config = AutoConfig.from_pretrained(model_dir)
    tokenizer = AutoTokenizer.from_pretrained(model_dir)
    model = AutoModelForTokenClassification.from_pretrained(model_dir)
    
    model.to(device)
    model.eval()

    return config, tokenizer, model

def predict(text, tokenizer, model, label_map, device = 'cuda'):
    # 将输入文本分词
    text_split = text.split()
    inputs = tokenizer(text_split, return_tensors="pt", truncation=True, is_split_into_words=True, max_length=512)
    input_ids = inputs["input_ids"].to(device)
    attention_mask = inputs["attention_mask"].to(device)

    # 使用模型进行预测
    with torch.no_grad():
        outputs = model(input_ids, attention_mask=attention_mask)
    # 获取预测结果matrix
        
    tokens = tokenizer.convert_ids_to_tokens(input_ids[0].tolist())
    predictions = outputs[0][0].cpu()
    return tokens, predictions


model_dir = "/home/data/t200404/bioinfo/P_subject/NLP/biobert/biobertModelWarehouse/model_from_trained/NER/4_combine_lipid_disease_ture_combine_3.2_data_from_MetaboliteNER_replace"  # 替换为你模型的保存路径
config, tokenizer, model = load_model_and_tokenizer(model_dir)
label_map = config.id2label
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 57
#      53     return text_split,txt_predictions
#      56 model_dir = "/home/data/t200404/bioinfo/P_subject/NLP/biobert/biobertModelWarehouse/model_from_trained/NER/4_combine_lipid_disease_ture_combine_3.2_data_from_MetaboliteNER_replace"  # 替换为你模型的保存路径
# ---> 57 config, tokenizer, model = load_model_and_tokenizer(model_dir)
#      58 label_map = config.id2label
#
# TypeError: load_model_and_tokenizer() missing 1 required positional argument: 'device'

# %%
import pickle
path_ = '/home/data/t200404/bioinfo/P_subject/NLP/biobert/datasets/for_recognize/download_paper_and_use_Auto-CORPus_deal_paper/deal/extract_result/'
with open(path_ + 'df_dict_lipid_and_disease_4_combine_lipid_disease_ture_combine_3.1_data_from_MetaboliteNER_replace_word2label.pkl','rb') as f:
    df_dict = pickle.load(f)

# %%
df_dict.keys()
# Out:
# dict_keys(['PMC10916870_bioc.json', 'PMC9529825_bioc.json', 'PMC9029192_bioc.json', 'PMC8917834_bioc.json', 'PMC10524330_bioc.json', 'PMC10925467_bioc.json', 'PMC10643672_bioc.json', 'PMC9599269_bioc.json', 'PMC11130959_bioc.json', 'PMC10436799_bioc.json', 'PMC10522101_bioc.json', 'PMC10510131_bioc.json', 'PMC9512465_bioc.json', 'PMC10588952_bioc.json', 'PMC10511619_bioc.json', 'PMC10888776_bioc.json', 'PMC10351449_bioc.json', 'PMC10531690_bioc.json', 'PMC9440283_bioc.json', 'PMC10605133_bioc.json', 'PMC9052151_bioc.json', 'PMC10909962_bioc.json', 'PMC9322850_bioc.json', 'PMC9134818_bioc.json', 'PMC10820332_bioc.json', 'PMC10513930_bioc.json', 'PMC8994740_bioc.json', 'PMC9083465_bioc.json', 'PMC10418585_bioc.json', 'PMC10495680_bioc.json', 'PMC10421736_bioc.json', 'PMC10418258_bioc.json', 'PMC9499571_bioc.json', 'PMC9693522_bioc.json', 'PMC10499024_bioc.json', 'PMC10785251_bioc.json', 'PMC10489812_bioc.json', 'PMC9523326_bioc.json', 'PMC9327366_bioc.json', 'PMC10826307_bioc.json', 'PMC9138405_bioc.json', 'PMC9646488_bioc.json', 'PMC10845207_bioc.json', 'PMC9122842_bioc.json', 'PMC9134151_bioc.json', 'PMC9548532_bioc.json', 'PMC6968861_bioc.json', 'PMC10516565_bioc.json', 'PMC9146561_bioc.json', 'PMC8990939_bioc.json', 'PMC10766617_bioc.json', 'PMC9710261_bioc.json', 'PMC9510413_bioc.json', 'PMC10410061_bioc.json', 'PMC10026384_bioc.json', 'PMC10999490_bioc.json', 'PMC9063006_bioc.json', 'PMC10651825_bioc.json', 'PMC11054623_bioc.json', 'PMC10965619_bioc.json', 'PMC10332421_bioc.json', 'PMC10665862_bioc.json', 'PMC10800357_bioc.json', 'PMC10835191_bioc.json', 'PMC10819672_bioc.json', 'PMC9623074_bioc.json', 'PMC10743306_bioc.json', 'PMC10456929_bioc.json', 'PMC9339474_bioc.json', 'PMC11099789_bioc.json', 'PMC8814823_bioc.json', 'PMC9207321_bioc.json', 'PMC10671639_bioc.json', 'PMC10773056_bioc.json', 'PMC9457222_bioc.json', 'PMC10697620_bioc.json', 'PMC9881540_bioc.json', 'PMC9160218_bioc.json', 'PMC10562722_bioc.json', 'PMC11080140_bioc.json', 'PMC9242022_bioc.json', 'PMC9151706_bioc.json', 'PMC9181703_bioc.json', 'PMC10320721_bioc.json', 'PMC10488057_bioc.json', 'PMC9174085_bioc.json', 'PMC10439247_bioc.json', 'PMC10886444_bioc.json', 'PMC9156495_bioc.json', 'PMC9319392_bioc.json', 'PMC10976809_bioc.json', 'PMC10103579_bioc.json', 'PMC10600383_bioc.json', 'PMC9192799_bioc.json', 'PMC10907603_bioc.json', 'PMC9090482_bioc.json', 'PMC9569465_bioc.json', 'PMC10970468_bioc.json', 'PMC11076307_bioc.json', 'PMC10320742_bioc.json', 'PMC10932050_bioc.json', 'PMC10849745_bioc.json', 'PMC8976580_bioc.json', 'PMC9504184_bioc.json', 'PMC9492538_bioc.json', 'PMC10517420_bioc.json', 'PMC9034302_bioc.json', 'PMC9470249_bioc.json', 'PMC9587889_bioc.json', 'PMC9505967_bioc.json', 'PMC10733568_bioc.json', 'PMC10949218_bioc.json', 'PMC10348772_bioc.json', 'PMC10819278_bioc.json', 'PMC10673587_bioc.json', 'PMC10455498_bioc.json', 'PMC10928265_bioc.json', 'PMC10480060_bioc.json', 'PMC10897514_bioc.json', 'PMC10723468_bioc.json', 'PMC10914730_bioc.json', 'PMC10384435_bioc.json', 'PMC10038389_bioc.json', 'PMC10734475_bioc.json', 'PMC9170690_bioc.json', 'PMC9230893_bioc.json', 'PMC9642993_bioc.json', 'PMC10419530_bioc.json', 'PMC10784323_bioc.json', 'PMC10975382_bioc.json', 'PMC9452301_bioc.json', 'PMC9632449_bioc.json', 'PMC10352119_bioc.json', 'PMC10425771_bioc.json', 'PMC11057186_bioc.json', 'PMC8785906_bioc.json', 'PMC10456680_bioc.json', 'PMC10857633_bioc.json', 'PMC11077833_bioc.json', 'PMC10634084_bioc.json', 'PMC10352238_bioc.json', 'PMC10384698_bioc.json', 'PMC10895975_bioc.json', 'PMC9339614_bioc.json', 'PMC9647768_bioc.json', 'PMC11088666_bioc.json', 'PMC4298754_bioc.json', 'PMC9387935_bioc.json', 'PMC10511504_bioc.json', 'PMC8804265_bioc.json', 'PMC11122055_bioc.json', 'PMC11094830_bioc.json', 'PMC9673737_bioc.json', 'PMC10444771_bioc.json', 'PMC10764485_bioc.json', 'PMC10507757_bioc.json', 'PMC10458137_bioc.json', 'PMC9599481_bioc.json', 'PMC9600510_bioc.json', 'PMC10839691_bioc.json', 'PMC9530349_bioc.json', 'PMC10509351_bioc.json', 'PM ...

# %%
df_ = df_dict['PMC8917834_bioc.json']
df_.iloc[0,:]
# Out:
# iao_name_1                                            document title
# iao_id_1                                                 IAO:0000305
# sentence           Sphingolipid-Induced Programmed Cell Death is ...
# sentence_number                                                    1
# split_sentence     Sphingolipid-Induced\nProgrammed\nCell\nDeath\...
# predictions                                                     None
# text_split         [Sphingolipid-Induced, Programmed, Cell, Death...
# txt_predictions    [4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, ...
# Name: 0, dtype: object

# %%
for i in range(len(df_['txt_predictions'])):
    if len(set(df_['txt_predictions'][i]))>1:
        # print(i)
        # print(df_['txt_predictions'][i])
        print(df_['sentence'][i])
        for j in range(len(df_['txt_predictions'][i])):
            if df_['txt_predictions'][i][j] != 4:
                print(df_['text_split'][i][j], df_['txt_predictions'][i][j])
# Out:
# Hydroxylation at C1 and C3 generates sphinganine (d18:0), the simplest form of LCB.
# sphinganine 2
# 2000, Brodersen et al.
# al. 3
# Recently it was shown that ENHANCED DISEASE SUSCEPTIBILITY 1 (EDS1) and PHYTOALEXIN DEFICIENT 4 (PAD4), two key players in regulation of SA synthesis in response to biological and abiotic stresses (Wiermer et al.
# PHYTOALEXIN 2
# DEFICIENT 3
# 2010, Saucedo-Garcia et al.
# et 3
# al. 3
# The sid2-2, eds1-2 and pad4-1 mutants were kindly provided by Prof. Christiane Gatz (University of Goettingen, Germany).
# Christiane 2
# Agnieszka Zienkiewicz,
# Department for Plant Biochemistry, Albrecht-von-Haller-Institute for Plant Sciences, University of Goettingen, Justus-von-Liebig-Weg 11, Goettingen 37077, Germany.
# Albrecht-von-Haller-Institute 2
# (2016) Orosomucoid proteins interact with the small subunit of serine palmitoyltransferase and contribute to sphingolipid homeostasis and stress responses in Arabidopsis.
# serine 2
# palmitoyltransferase 3
# (2011) Different roles of Enhanced Disease Susceptibility1 (EDS1) bound to and dissociated from Phytoalexin Deficient4 (PAD4) in Arabidopsis immunity.
# Phytoalexin 2
# Deficient4 3
# Saucedo-García M., Guevara-García A., González-Solís A., Cruz-García F., Vázquez-Santana S., Markham J.E., et al.
# González-Solís 2
# Yanagawa D., Ishikawa T. and Imai H. (2017) Synthesis and degradation of long-chain base phosphates affect fumonisin B1-induced cell death in Arabidopsis thaliana.
# B1-induced 3

# %%
text_ = 'Hydroxylation at C1 and C3 generates sphinganine (d18:0), the simplest form of LCB.'
predict(text_,tokenizer,model,label_map,device = 'cuda')
# Out:
# (['[CLS]',
#   'h',
#   '##ydro',
#   '##xy',
#   '##lation',
#   'at',
#   'c',
#   '##1',
#   'and',
#   'c',
#   '##3',
#   'generates',
#   's',
#   '##phi',
#   '##nga',
#   '##nine',
#   '(',
#   'd',
#   '##18',
#   ':',
#   '0',
#   ')',
#   ',',
#   'the',
#   'simplest',
#   'form',
#   'of',
#   'l',
#   '##c',
#   '##b',
#   '.',
#   '[SEP]'],
#  tensor([[-11.5979, -12.0405,  -4.2480,  -7.0449,   8.7545],
#          [-11.3651, -11.9584,  -5.0264,  -7.6798,   9.1329],
#          [-11.2527, -12.0310,  -4.8509,  -7.6502,   8.9388],
#          [-11.3015, -12.1064,  -4.2448,  -7.6327,   8.4771],
#          [-11.3528, -11.9370,  -4.7792,  -7.5037,   8.7867],
#          [-11.7667, -12.5819,  -4.8824,  -7.5821,   9.2205],
#          [-11.0883, -12.0056,  -5.1577,  -7.5418,   9.2210],
#          [-11.3911, -12.3407,  -4.8599,  -7.6260,   9.1165],
#          [-11.1128, -11.9133,  -5.1442,  -7.5462,   9.1477],
#          [-11.0246, -11.7948,  -5.2795,  -7.4045,   9.2204],
#          [-11.5839, -12.6255,  -4.8079,  -7.5948,   9.1376],
#          [-11.3385, -12.1225,  -5.0631,  -7.3342,   9.3090],
#          [ -7.3621,  -9.5138,   2.4959,  -4.9955,   1.3898],
#          [ -8.3739, -10.1447,   1.6103,  -5.5763,   2.6063],
#          [ -9.7561, -10.3622,   0.2617,  -5.7084,   4.3968],
#          [ -9.8303, -10.7969,   1.1217,  -5.7392,   3.5099],
#          [-11.7959, -12.3491,  -4.5093,  -7.3795,   8.8372],
#          [-11.4216, -12.4702,  -4.6796,  -7.8099,   9.1858],
#          [-11.9952, -13.1827,  -3.1625,  -8.3112,   8.3444],
#          [-11.2962, -12.1258,  -5.1692,  -7.4520,   9.1805],
#          [-11.3925, -12.4291,  -4.8239,  -7.8270,   9.1817],
#          [-11.1980, -12.2352,  -5.0280,  -7.5174,   9.2754],
#          [-10.7558, -11.8612,  -5.1168,  -7.4675,   9.2203],
#          [-11.0872, -12.0683,  -5.2409,  -7.3294,   9.2910],
#          [-11.1614, -12.1280,  -5.3730,  -7.2148,   9.2808],
#          [-11.1688, -12.0637,  -5.4338,  -7.2115,   9.2594],
#          [-10.9360, -11.8919,  -5.4373,  -7.2457,   9.2607],
#          [-11.0188, -12.1974,  -5.0912,  -7.6448,   9.2201],
#          [-11.8289, -12.8089,  -4.3151,  -8.0941,   8.8886],
#          [-11.4758, -12.4881,  -5.0754,  -7.4451,   9.1327],
#          [-12.4910, -14.4423,  -2.1445,  -7.0581,   7.5163],
#          [-12.4488, -14.4050,  -2.1748,  -7.0457,   7.5204]]))

# %%
# Out:
# BertTokenizerFast(name_or_path='/home/data/t200404/bioinfo/P_subject/NLP/biobert/biobertModelWarehouse/model_from_trained/NER/4_combine_lipid_disease_ture_combine_3', vocab_size=28996, model_max_length=1000000000000000019884624838656, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'}, clean_up_tokenization_spaces=True)

# %%
model_name = '4_combine_lipid_disease_ture_combine_2'
model_dir = "/home/data/t200404/bioinfo/P_subject/NLP/biobert/biobertModelWarehouse/model_from_trained/NER/"  # 替换模型的保存路径
model_dir = model_dir + model_name + "/"
config, tokenizer, model = load_model_and_tokenizer(model_dir,device = 'cuda')
label_map = config.id2label

# %%
import pickle

path_ = '/home/data/t200404/bioinfo/P_subject/NLP/biobert/datasets/for_recognize/download_paper_and_use_Auto-CORPus_deal_paper/deal/extract_result/'
with open(path_ + 'df_dict_lipid_and_disease_4_combine_lipid_disease_ture_combine_3.1_data_from_MetaboliteNER_replace_word2label.pkl','rb') as f:
    df_dict = pickle.load(f)

# PMC_bioc_name = 'PMC11130959_bioc.json'
dict_keys_list = list(df_dict.keys())
# start_index = dict_keys_list.index(PMC_bioc_name)
# for PMC_bioc_name in dict_keys_list[start_index:]:    
save_batch = 10
index_ = 0
for PMC_bioc_name in dict_keys_list:    

    if 'score' in df_dict[PMC_bioc_name].columns:
        continue
    else:
        print(PMC_bioc_name)
        results = df_dict[PMC_bioc_name]['sentence'].apply(
            lambda x: predict(x, tokenizer, model, label_map, device='cuda')
        )
        df_dict[PMC_bioc_name]['tokens'], df_dict[PMC_bioc_name]['score'] = zip(*results)
        index_ += 1
        if index_ % save_batch == 0:
            with open(path_+ f'lipid_and_disease_{model_name}'+'_token2score'+'.pkl','wb') as f:
                pickle.dump(df_dict, f)

# %% [markdown]
# ## Become image

# %%
from PIL import Image, ImageDraw, ImageFont

def highlight_text(text, word, highlight_color="yellow", font_path="arial.ttf", font_size=24, output_path="output.png"):
    # Initialize font
    font = ImageFont.truetype(font_path, font_size)
    
    # Create image with white background
    lines = text.split('\n')
    max_line_width = max([font.getsize(line)[0] for line in lines])
    image_height = font_size * len(lines) + 20
    image = Image.new('RGB', (max_line_width + 20, image_height), color = (255, 255, 255))
    draw = ImageDraw.Draw(image)
    
    y_text = 10
    for line in lines:
        words = line.split(' ')
        x_text = 10
        for w in words:
            word_width, word_height = draw.textsize(w + ' ', font=font)
            if w == word:
                # Draw highlighted rectangle
                draw.rectangle([x_text, y_text, x_text + word_width, y_text + word_height], fill=highlight_color)
            draw.text((x_text, y_text), w + ' ', font=font, fill=(0, 0, 0))
            x_text += word_width
        y_text += word_height

    # Save the image
    image.save(output_path)
    print(f"Image saved to {output_path}")

# Example usage
text = "This is a sample text where a specific word is highlighted."
word_to_highlight = "specific"
highlight_text(text, word_to_highlight, highlight_color="yellow", font_path="arial.ttf", font_size=24, output_path="output.png")

# %%
from PIL import Image, ImageDraw, ImageFont

def highlight_text(text, word, highlight_color="yellow", font_size=24, output_path="output.png"):
    # Initialize default font
    try:
        font = ImageFont.truetype("arial.ttf", font_size)
    except OSError:
        font = ImageFont.load_default()
    
    # Create image with white background
    lines = text.split('\n')
    max_line_width = max([font.getsize(line)[0] for line in lines])
    image_height = font_size * len(lines) + 20
    image = Image.new('RGB', (max_line_width + 20, image_height), color=(255, 255, 255))
    draw = ImageDraw.Draw(image)
    
    y_text = 10
    for line in lines:
        words = line.split(' ')
        x_text = 10
        for w in words:
            word_width, word_height = draw.textsize(w + ' ', font=font)
            if w == word:
                # Draw highlighted rectangle
                draw.rectangle([x_text, y_text, x_text + word_width, y_text + word_height], fill=highlight_color)
            draw.text((x_text, y_text), w + ' ', font=font, fill=(0, 0, 0))
            x_text += word_width
        y_text += word_height

    # Save the image
    image.save(output_path)
    print(f"Image saved to {output_path}")

# Example usage
text = "This is a sample text where a specific word is highlighted."
word_to_highlight = "specific"
highlight_text(text, word_to_highlight, highlight_color="yellow", font_size=24, output_path="output.png")

# %%
from PIL import Image, ImageDraw, ImageFont

# 定义要处理的文本和标签
tokens = prediction['tokens']
labels = prediction['labels']
# 获取处理后的words和对应的labels
processed_words = prediction['tokens'][1:-1]  # 去掉[CLS]和[SEP]
processed_labels = prediction['labels'][1:-1]  # 去掉[CLS]和[SEP]

# 定义颜色
color_map = {
    "B-disease": "red",
    "I-disease": "red",
    "B-lipid": "blue",
    "I-lipid": "blue"
}

# 恢复原始文本
def reconstruct_text(tokens):
    words = []
    current_word = ""
    for token in tokens:
        if token.startswith("##"):
            current_word += token[2:]
        else:
            if current_word:
                words.append(current_word)
            current_word = token
    if current_word:
        words.append(current_word)
    return words

words = reconstruct_text(tokens[1:-1])  # 去掉[CLS]和[SEP]标记

# 创建一个函数来绘制带有高亮的文本
def draw_highlighted_text(words, labels, color_map, font_path="DejaVuSans-Bold.ttf", font_size=24, output_path="output.png"):
    # 初始化字体
    try:
        font = ImageFont.truetype(font_path, font_size)
    except OSError:
        font = ImageFont.load_default()
    
    # 创建白色背景图像
    image_width = 600  # 增加宽度以提高分辨率
    image_height = 600  # 增加高度以提高分辨率
    image = Image.new('RGB', (image_width, image_height), color=(255, 255, 255))
    draw = ImageDraw.Draw(image)
    
    x_text = 10
    y_text = 10
    
    for word, label in zip(words, labels):
        word_width, word_height = draw.textsize(word, font=font)
        color = color_map.get(label, None)
        if color:
            draw.rectangle([x_text, y_text, x_text + word_width, y_text + word_height], fill=color)
        draw.text((x_text, y_text), word, font=font, fill=(0, 0, 0))
        x_text += word_width + 5  # 添加一些空隙
        
        # 换行处理
        if x_text > image_width - 100:
            x_text = 10
            y_text += word_height + 10
    
    # 保存图片
    image.save(output_path)
    print(f"Image saved to {output_path}")


# 绘制并保存图片
draw_highlighted_text(processed_words, processed_labels, color_map, font_size=24, output_path="output.png")

# %%
for token, label in zip(tokens, labels):
    if label != 'O':
        print(token, label)
# Out:
# d I-lipid
# la B-lipid
# ##cc B-lipid
# ##er I-lipid
# d I-lipid
# ##18 I-lipid
# al B-disease
# ##heimer I-disease
# ' I-disease
# s I-disease
# disease I-disease

# %%
import pickle
with open('df_dict_only_lipid.pkl','rb') as f:
    df_dict_only_lipid = pickle.load(f)

have = 0
nohave = 0
for key in df_dict_only_lipid.keys():
    # print(key)
    if 'predictions_lipid' in df_dict_only_lipid[key].columns:
        if len(set(df_dict_only_lipid[key]['predictions_lipid'])) > 1:
            print(set(df_dict_only_lipid[key]['predictions_lipid']))
        have += 1
    else:
        print(f'{key},no predictions_lipid')
        nohave += 1
print(f'have predictions_lipid: {have}, no predictions_lipid: {nohave}')
# Out:
# PMC9481132_bioc.json,no predictions_lipid
# PMC9552013_bioc.json,no predictions_lipid
# PMC10361545_bioc.json,no predictions_lipid
# PMC10497391_bioc.json,no predictions_lipid
# PMC9305268_bioc.json,no predictions_lipid
# PMC10667563_bioc.json,no predictions_lipid
# PMC10760103_bioc.json,no predictions_lipid
# PMC7345851_bioc.json,no predictions_lipid
# PMC10808295_bioc.json,no predictions_lipid
# PMC10412683_bioc.json,no predictions_lipid
# PMC10537536_bioc.json,no predictions_lipid
# PMC9668183_bioc.json,no predictions_lipid
# PMC10499237_bioc.json,no predictions_lipid
# PMC9225104_bioc.json,no predictions_lipid
# PMC9319954_bioc.json,no predictions_lipid
# PMC9406929_bioc.json,no predictions_lipid
# PMC11141675_bioc.json,no predictions_lipid
# PMC10954412_bioc.json,no predictions_lipid
# PMC9127619_bioc.json,no predictions_lipid
# PMC10746288_bioc.json,no predictions_lipid
# PMC9137556_bioc.json,no predictions_lipid
# PMC9280915_bioc.json,no predictions_lipid
# PMC10846697_bioc.json,no predictions_lipid
# PMC10479895_bioc.json,no predictions_lipid
# PMC9026385_bioc.json,no predictions_lipid
# PMC8974344_bioc.json,no predictions_lipid
# PMC10253587_bioc.json,no predictions_lipid
# PMC9033131_bioc.json,no predictions_lipid
# PMC10972802_bioc.json,no predictions_lipid
# PMC9678881_bioc.json,no predictions_lipid
# PMC9271868_bioc.json,no predictions_lipid
# PMC10923689_bioc.json,no predictions_lipid
# PMC9146183_bioc.json,no predictions_lipid
# PMC10719137_bioc.json,no predictions_lipid
# PMC8917653_bioc.json,no predictions_lipid
# PMC10880942_bioc.json,no predictions_lipid
# PMC9675570_bioc.json,no predictions_lipid
# PMC9181022_bioc.json,no predictions_lipid
# PMC10915097_bioc.json,no predictions_lipid
# PMC11141923_bioc.json,no predictions_lipid
# PMC10576442_bioc.json,no predictions_lipid
# PMC11100568_bioc.json,no predictions_lipid
# PMC9103399_bioc.json,no predictions_lipid
# PMC10692693_bioc.json,no predictions_lipid
# PMC10660817_bioc.json,no predictions_lipid
# PMC10486416_bioc.json,no predictions_lipid
# PMC10895977_bioc.json,no predictions_lipid
# PMC9011034_bioc.json,no predictions_lipid
# PMC9135947_bioc.json,no predictions_lipid
# PMC10504721_bioc.json,no predictions_lipid
# PMC11048107_bioc.json,no predictions_lipid
# PMC11002810_bioc.json,no predictions_lipid
# PMC10932381_bioc.json,no predictions_lipid
# PMC9514057_bioc.json,no predictions_lipid
# PMC9549873_bioc.json,no predictions_lipid
# PMC11058159_bioc.json,no predictions_lipid
# PMC10473750_bioc.json,no predictions_lipid
# PMC10456080_bioc.json,no predictions_lipid
# PMC10880366_bioc.json,no predictions_lipid
# PMC10910801_bioc.json,no predictions_lipid
# PMC9051397_bioc.json,no predictions_lipid
# PMC9368995_bioc.json,no predictions_lipid
# PMC11053976_bioc.json,no predictions_lipid
# PMC10377844_bioc.json,no predictions_lipid
# PMC10515780_bioc.json,no predictions_lipid
# PMC9695307_bioc.json,no predictions_lipid
# PMC9058236_bioc.json,no predictions_lipid
# PMC9577179_bioc.json,no predictions_lipid
# PMC10721521_bioc.json,no predictions_lipid
# PMC10539639_bioc.json,no predictions_lipid
# PMC10493432_bioc.json,no predictions_lipid
# PMC10460540_bioc.json,no predictions_lipid
# PMC9368002_bioc.json,no predictions_lipid
# PMC10333360_bioc.json,no predictions_lipid
# PMC10151196_bioc.json,no predictions_lipid
# PMC9893913_bioc.json,no predictions_lipid
# PMC9611871_bioc.json,no predictions_lipid
# PMC10630469_bioc.json,no predictions_lipid
# PMC9465305_bioc.json,no predictions_lipid
# PMC10144665_bioc.json,no predictions_lipid
# PMC8957608_bioc.json,no predictions_lipid
# PMC9039073_bioc.json,no predictions_lipid
# PMC9891107_bioc.json,no predictions_lipid
# PMC10551651_bioc.json,no predictions_lipid
# PMC10881635_bioc.json,no predictions_lipid
# PMC10921719_bioc.json,no predictions_lipid
# PMC11156661_bioc.json,no predictions_lipid
# PMC10372136_bioc.json,no predictions_lipid
# PMC9724488_bioc.json,no predictions_lipid
# PMC10972397_bioc.json,no predictions_lipid
# PMC10827074_bioc.json,no predictions_lipid
# PMC8982503_bioc.json,no predictions_lipid
# PMC9337250_bioc.json,no predictions_lipid
# PMC9146557_bioc.json,no predictions_lipid
# PMC10579282_bioc.json,no predictions_lipid
# PMC10548646_bioc.json,no predictions_lipid
# PMC9654699_bioc.json,no predictions_lipid
# PMC10828605_bioc.json,no predictions_lipid
# PMC10568566_bioc.json,no predictions_lipid
# PMC9500627_bioc.json,no predictions_lipid
# PMC10755605_bioc.json,no predictions_lipid
# PMC9181499_bioc.json,no predictions_lipid
# PMC9332783_bioc.json,no predictions_lipid
# PMC10234690_bioc.json,no predictions_lipid
# PMC10593953_bioc.json,no predictions_lipid
# PMC11079853_bioc.json,no predictions_lipid
# PMC9607865_bioc.json,no predictions_lipid
# PMC10651623_bioc.json,no predictions_lipid
# PMC9146605_bioc.json,no predictions_lipid
# PMC10246148_bioc.json,no predictions_lipid
# PMC10663915_bioc.json,no predictions_lipid
# PMC9062978_bioc.json,no predictions_lipid
# PMC9480494_bioc.json,no predictions_lipid
# PMC10393401_bioc.json,no predictions_lipid
# PMC10708484_bioc.json,no predictions_lipid
# PMC11000317_bioc.json,no predictions_lipid
# PMC9479707_bioc.json,no predictions_lipid
# PMC10423493_bioc.json,no predictions_lipid
# PMC9053645_bioc.json,no predictions_lipid
# PMC8989825_bioc.json,no predictions_lipid
# PMC10844764_bioc.json,no predictions_lipid
# PMC9612025_bioc.json,no predictions_lipid
# PMC10402111_bioc.json,no predictions_lipid
# PMC11064913_bioc.json,no predictions_lipid
# PMC11122033_bioc.json,no predictions_lipid
# PMC10618167_bioc.json,no predictions_lipid
# PMC10753995_bioc.json,no predictions_lipid
# PMC9748622_bioc.json,no predictions_lipid
# PMC8950643_bioc.json,no predictions_lipid
# PMC10786767_bioc.json,no predictions_lipid
# PMC11050812_bioc.json,no predictions_lipid
# PMC9138383_bioc.json,no predictions_lipid
# PMC9352691_bioc.json,no predictions_lipid
# PMC10770321_bioc.json,no predictions_lipid
# PMC9174089_bioc.json,no predictions_lipid
# PMC8960862_bioc.json,no predictions_lipid
# PMC9002953_bioc.json,no predictions_lipid
# PMC10337513_bioc.json,no predictions_lipid
# PMC10902711_bioc.json,no predictions_lipid
# PMC10765891_bioc.json,no predictions_lipid
# PMC9117487_bioc.json,no predictions_lipid
# PMC10889776_bioc.json,no predictions_lipid
# PMC9709595_bioc.json,no predictions_lipid
# PMC10518786_bioc.json,no predictions_lipid
# PMC10967382_bioc.json,no predictions_lipid
# PMC11047005_bioc.json,no predictions_lipid
# PMC10703578_bioc.json,no predictions_lipid
# PMC9249739_bioc.json,no predictions_lipid
# PMC10547714_bioc.json,no predictions_lipid
# PMC10945898_bioc.json,no predictions_lipid
# PMC9501626_bioc.json,no predictions_lipid
# PMC10380980_bioc.json,no predictions_lipid
# PMC10820643_bioc.json,no predictions_lipid
# PMC3266543_bioc.json,no predictions_lipid
# PMC10680807_bioc.json,no predictions_lipid
# PMC10758476_bioc.json,no predictions_lipid
# PMC9078351_bioc.json,no predictions_lipid
# PMC9317423_bioc.json,no predictions_lipid
# PMC9645366_bioc.json,no predictions_lipid
# PMC9604335_bioc.json,no predictions_lipid
# PMC10759727_bioc.json,no predictions_lipid
# PMC9630229_bioc.json,no predictions_lipid
# PMC9019515_bioc.json,no predictions_lipid
# PMC9355963_bioc.json,no predictions_lipid
# PMC10968313_bioc.json,no predictions_lipid
# PMC10327322_bioc.json,no predictions_lipid
# PMC9279988_bioc.json,no predictions_lipid
# PMC10338492_bioc.json,no predictions_lipid
# PMC9462509_bioc.json,no predictions_lipid
# PMC10957925_bioc.json,no predictions_lipid
# PMC11086901_bioc.json,no predictions_lipid
# PMC10532006_bioc.json,no predictions_lipid
# PMC8807873_bioc.json,no predictions_lipid
# PMC9709465_bioc.json,no predictions_lipid
# PMC9409395_bioc.json,no predictions_lipid
# PMC9699282_bioc.json,no predictions_lipid
# PMC9599756_bioc.json,no predictions_lipid
# PMC10503653_bioc.json,no predictions_lipid
# PMC9178408_bioc.json,no predictions_lipid
# PMC10454326_bioc.json,no predictions_lipid
# PMC10882644_bioc.json,no predictions_lipid
# PMC10940770_bioc.json,no predictions_lipid
# PMC10848961_bioc.json,no predictions_lipid
# PMC10327029_bioc.json,no predictions_lipid
# PMC10671390_bioc.json,no predictions_lipid
# PMC10871284_bioc.json,no predictions_lipid
# PMC10740609_bioc.json,no predictions_lipid
# PMC11005404_bioc.json,no predictions_lipid
# PMC9699637_bioc.json,no predictions_lipid
# PMC9237713_bioc.json,no predictions_lipid
# PMC10408111_bioc.json,no predictions_lipid
# PMC9332067_bioc.json,no predictions_lipid
# PMC9159377_bioc.json,no predictions_lipid
# PMC10722991_bioc.json,no predictions_lipid
# PMC10484938_bioc.json,no predictions_lipid
# PMC11009500_bioc.json,no predictions_lipid
# PMC10462091_bioc.json,no predictions_lipid
# PMC10742328_bioc.json,no predictions_lipid
# PMC10553840_bioc.json,no predictions_lipid
# PMC9235897_bioc.json,no predictions_lipid
# PMC10560374_bioc.json,no predictions_lipid
# PMC8990168_bioc.json,no predictions_lipid
# PMC9274766_bioc.json,no predictions_lipid
# PMC9086493_bioc.json,no predictions_lipid
# PMC9828243_bioc.json,no predictions_lipid
# PMC9312468_bioc.json,no predictions_lipid
# PMC9344778_bioc.json,no predictions_lipid
# PMC10607182_bioc.json,no predictions_lipid
# PMC10685602_bioc.json,no predictions_lipid
# PMC9614236_bioc.json,no predictions_lipid
# PMC11013466_bioc.json,no predictions_lipid
# PMC9213752_bioc.json,no predictions_lipid
# PMC9696092_bioc.json,no predictions_lipid
# PMC8947234_bioc.json,no predictions_lipid
# PMC9006858_bioc.json,no predictions_lipid
# PMC9010367_bioc.json,no predictions_lipid
# PMC10981308_bioc.json,no predictions_lipid
# PMC10464166_bioc.json,no predictions_lipid
# PMC11042293_bioc.json,no predictions_lipid
# PMC9225617_bioc.json,no predictions_lipid
# PMC10320374_bioc.json,no predictions_lipid
# PMC9434798_bioc.json,no predictions_lipid
# PMC9479978_bioc.json,no predictions_lipid
# PMC8949028_bioc.json,no predictions_lipid
# PMC10537766_bioc.json,no predictions_lipid
# PMC9405726_bioc.json,no predictions_lipid
# PMC10469212_bioc.json,no predictions_lipid
# PMC9458637_bioc.json,no predictions_lipid
# PMC9597708_bioc.json,no predictions_lipid
# PMC8995063_bioc.json,no predictions_lipid
# PMC10881354_bioc.json,no predictions_lipid
# PMC10516085_bioc.json,no predictions_lipid
# PMC9006154_bioc.json,no predictions_lipid
# PMC9312214_bioc.json,no predictions_lipid
# PMC9457360_bioc.json,no predictions_lipid
# PMC11118013_bioc.json,no predictions_lipid
# PMC10884415_bioc.json,no predictions_lipid
# PMC9456773_bioc.json,no predictions_lipid
# PMC10624405_bioc.json,no predictions_lipid
# PMC9369067_bioc.json,no predictions_lipid
# PMC11042515_bioc.json,no predictions_lipid
# PMC11154292_bioc.json,no predictions_lipid
# PMC10551860_bioc.json,no predictions_lipid
# PMC8945048_bioc.json,no predictions_lipid
# PMC9072861_bioc.json,no predictions_lipid
# PMC9393265_bioc.json,no predictions_lipid
# PMC10357504_bioc.json,no predictions_lipid
# PMC10867256_bioc.json,no predictions_lipid
# PMC10463951_bioc.json,no predictions_lipid
# PMC9154741_bioc.json,no predictions_lipid
# PMC9622472_bioc.json,no predictions_lipid
# PMC10474074_bioc.json,no predictions_lipid
# PMC9693407_bioc.json,no predictions_lipid
# PMC10124143_bioc.json,no predictions_lipid
# PMC10704844_bioc.json,no predictions_lipid
# PMC9065415_bioc.json,no predictions_lipid
# PMC9448719_bioc.json,no predictions_lipid
# PMC10850344_bioc.json,no predictions_lipid
# PMC10689447_bioc.json,no predictions_lipid
# PMC10827501_bioc.json,no predictions_lipid
# PMC9775246_bioc.json,no predictions_lipid
# PMC10611854_bioc.json,no predictions_lipid
# PMC9775665_bioc.json,no predictions_lipid
# PMC10648092_bioc.json,no predictions_lipid
# PMC9315580_bioc.json,no predictions_lipid
# PMC9197191_bioc.json,no predictions_lipid
# PMC10680892_bioc.json,no predictions_lipid
# PMC9228171_bioc.json,no predictions_lipid
# PMC10742042_bioc.json,no predictions_lipid
# PMC9271640_bioc.json,no predictions_lipid
# PMC9757867_bioc.json,no predictions_lipid
# PMC11107249_bioc.json,no predictions_lipid
# PMC9254886_bioc.json,no predictions_lipid
# PMC9472780_bioc.json,no predictions_lipid
# PMC10649202_bioc.json,no predictions_lipid
# PMC9396035_bioc.json,no predictions_lipid
# PMC9287789_bioc.json,no predictions_lipid
# PMC11083524_bioc.json,no predictions_lipid
# PMC10384620_bioc.json,no predictions_lipid
# PMC10954972_bioc.json,no predictions_lipid
# PMC10465965_bioc.json,no predictions_lipid
# PMC11106344_bioc.json,no predictions_lipid
# PMC11124303_bioc.json,no predictions_lipid
# PMC9324278_bioc.json,no predictions_lipid
# PMC9265961_bioc.json,no predictions_lipid
# PMC7613028_bioc.json,no predictions_lipid
# PMC9690481_bioc.json,no predictions_lipid
# PMC9266848_bioc.json,no predictions_lipid
# PMC8962106_bioc.json,no predictions_lipid
# PMC11049154_bioc.json,no predictions_lipid
# PMC10715237_bioc.json,no predictions_lipid
# PMC10858823_bioc.json,no predictions_lipid
# PMC10741016_bioc.json,no predictions_lipid
# PMC10940674_bioc.json,no predictions_lipid
# PMC11100735_bioc.json,no predictions_lipid
# PMC9688479_bioc.json,no predictions_lipid
# PMC10920423_bioc.json,no predictions_lipid
# PMC9204892_bioc.json,no predictions_lipid
# PMC9423774_bioc.json,no predictions_lipid
# PMC10581039_bioc.json,no predictions_lipid
# PMC10673379_bioc.json,no predictions_lipid
# PMC9594140_bioc.json,no predictions_lipid
# PMC9261347_bioc.json,no predictions_lipid
# PMC10670336_bioc.json,no predictions_lipid
# PMC11114474_bioc.json,no predictions_lipid
# PMC10874778_bioc.json,no predictions_lipid
# PMC10894287_bioc.json,no predictions_lipid
# PMC10641532_bioc.json,no predictions_lipid
# PMC10844835_bioc.json,no predictions_lipid
# PMC9683386_bioc.json,no predictions_lipid
# PMC10796296_bioc.json,no predictions_lipid
# PMC10906217_bioc.json,no predictions_lipid
# PMC10316035_bioc.json,no predictions_lipid
# PMC10745121_bioc.json,no predictions_lipid
# PMC9428462_bioc.json,no predictions_lipid
# PMC9804612_bioc.json,no predictions_lipid
# PMC10888986_bioc.json,no predictions_lipid
# PMC9598654_bioc.json,no predictions_lipid
# PMC10777643_bioc.json,no predictions_lipid
# PMC10812416_bioc.json,no predictions_lipid
# PMC10891938_bioc.json,no predictions_lipid
# PMC9632042_bioc.json,no predictions_lipid
# PMC10408177_bioc.json,no predictions_lipid
# PMC8881568_bioc.json,no predictions_lipid
# PMC8981695_bioc.json,no predictions_lipid
# PMC10463967_bioc.json,no predictions_lipid
# PMC9197994_bioc.json,no predictions_lipid
# PMC10524606_bioc.json,no predictions_lipid
# PMC9085356_bioc.json,no predictions_lipid
# PMC9168377_bioc.json,no predictions_lipid
# PMC11141868_bioc.json,no predictions_lipid
# PMC9615322_bioc.json,no predictions_lipid
# PMC10499464_bioc.json,no predictions_lipid
# PMC9377334_bioc.json,no predictions_lipid
# PMC9352902_bioc.json,no predictions_lipid
# PMC10229544_bioc.json,no predictions_lipid
# PMC10234834_bioc.json,no predictions_lipid
# PMC10334607_bioc.json,no predictions_lipid
# PMC9126486_bioc.json,no predictions_lipid
# PMC10361602_bioc.json,no predictions_lipid
# PMC9439902_bioc.json,no predictions_lipid
# PMC9786902_bioc.json,no predictions_lipid
# PMC9268751_bioc.json,no predictions_lipid
# PMC10777051_bioc.json,no predictions_lipid
# PMC10562429_bioc.json,no predictions_lipid
# PMC11109210_bioc.json,no predictions_lipid
# PMC9315603_bioc.json,no predictions_lipid
# PMC10776888_bioc.json,no predictions_lipid
# PMC11067451_bioc.json,no predictions_lipid
# PMC10707116_bioc.json,no predictions_lipid
# PMC9208599_bioc.json,no predictions_lipid
# PMC9600727_bioc.json,no predictions_lipid
# PMC10930281_bioc.json,no predictions_lipid
# PMC10375787_bioc.json,no predictions_lipid
# PMC10330318_bioc.json,no predictions_lipid
# PMC10386220_bioc.json,no predictions_lipid
# PMC10799922_bioc.json,no predictions_lipid
# PMC8945792_bioc.json,no predictions_lipid
# PMC9534783_bioc.json,no predictions_lipid
# PMC9698586_bioc.json,no predictions_lipid
# PMC11042380_bioc.json,no predictions_lipid
# PMC9505575_bioc.json,no predictions_lipid
# PMC10157813_bioc.json,no predictions_lipid
# PMC10438872_bioc.json,no predictions_lipid
# PMC10987564_bioc.json,no predictions_lipid
# PMC10713386_bioc.json,no predictions_lipid
# PMC9622473_bioc.json,no predictions_lipid
# PMC10808414_bioc.json,no predictions_lipid
# PMC10568095_bioc.json,no predictions_lipid
# PMC9025801_bioc.json,no predictions_lipid
# PMC10506103_bioc.json,no predictions_lipid
# PMC11089707_bioc.json,no predictions_lipid
# PMC10970721_bioc.json,no predictions_lipid
# PMC10776612_bioc.json,no predictions_lipid
# PMC10425750_bioc.json,no predictions_lipid
# PMC10442885_bioc.json,no predictions_lipid
# PMC8995832_bioc.json,no predictions_lipid
# PMC9371754_bioc.json,no predictions_lipid
# PMC9500723_bioc.json,no predictions_lipid
# PMC9605047_bioc.json,no predictions_lipid
# PMC11087356_bioc.json,no predictions_lipid
# PMC9287950_bioc.json,no predictions_lipid
# PMC11142272_bioc.json,no predictions_lipid
# PMC10881686_bioc.json,no predictions_lipid
# PMC10771670_bioc.json,no predictions_lipid
# PMC10849633_bioc.json,no predictions_lipid
# PMC10839226_bioc.json,no predictions_lipid
# PMC10550783_bioc.json,no predictions_lipid
# PMC10564178_bioc.json,no predictions_lipid
# PMC9610966_bioc.json,no predictions_lipid
# PMC10613889_bioc.json,no predictions_lipid
# PMC11053339_bioc.json,no predictions_lipid
# PMC9870060_bioc.json,no predictions_lipid
# PMC10646540_bioc.json,no predictions_lipid
# PMC8975934_bioc.json,no predictions_lipid
# PMC10589346_bioc.json,no predictions_lipid
# PMC10154216_bioc.json,no predictions_lipid
# PMC9420484_bioc.json,no predictions_lipid
# PMC9612789_bioc.json,no predictions_lipid
# PMC11010376_bioc.json,no predictions_lipid
# PMC8991125_bioc.json,no predictions_lipid
# PMC9314906_bioc.json,no predictions_lipid
# PMC9407502_bioc.json,no predictions_lipid
# PMC10870777_bioc.json,no predictions_lipid
# PMC10777844_bioc.json,no predictions_lipid
# PMC9295441_bioc.json,no predictions_lipid
# PMC10921537_bioc.json,no predictions_lipid
# PMC9086146_bioc.json,no predictions_lipid
# PMC9009047_bioc.json,no predictions_lipid
# PMC9234243_bioc.json,no predictions_lipid
# PMC9564215_bioc.json,no predictions_lipid
# PMC10731584_bioc.json,no predictions_lipid
# PMC11120743_bioc.json,no predictions_lipid
# PMC10536708_bioc.json,no predictions_lipid
# PMC10499660_bioc.json,no predictions_lipid
# PMC9289478_bioc.json,no predictions_lipid
# PMC10555997_bioc.json,no predictions_lipid
# PMC10368927_bioc.json,no predictions_lipid
# PMC9219555_bioc.json,no predictions_lipid
# PMC10610231_bioc.json,no predictions_lipid
# PMC9050548_bioc.json,no predictions_lipid
# PMC10820779_bioc.json,no predictions_lipid
# PMC8975940_bioc.json,no predictions_lipid
# PMC10951062_bioc.json,no predictions_lipid
# PMC10557709_bioc.json,no predictions_lipid
# PMC10787879_bioc.json,no predictions_lipid
# PMC9471008_bioc.json,no predictions_lipid
# PMC9138805_bioc.json,no predictions_lipid
# PMC10879031_bioc.json,no predictions_lipid
# PMC9454634_bioc.json,no predictions_lipid
# PMC10782027_bioc.json,no predictions_lipid
# PMC9478754_bioc.json,no predictions_lipid
# PMC9149947_bioc.json,no predictions_lipid
# PMC10970785_bioc.json,no predictions_lipid
# PMC10895972_bioc.json,no predictions_lipid
# PMC10401778_bioc.json,no predictions_lipid
# PMC11062938_bioc.json,no predictions_lipid
# PMC9178378_bioc.json,no predictions_lipid
# PMC9693482_bioc.json,no predictions_lipid
# PMC11056164_bioc.json,no predictions_lipid
# PMC11083124_bioc.json,no predictions_lipid
# PMC9241667_bioc.json,no predictions_lipid
# PMC10525117_bioc.json,no predictions_lipid
# PMC11068142_bioc.json,no predictions_lipid
# PMC11039673_bioc.json,no predictions_lipid
# PMC10647642_bioc.json,no predictions_lipid
# PMC9377946_bioc.json,no predictions_lipid
# PMC10580008_bioc.json,no predictions_lipid
# PMC9986357_bioc.json,no predictions_lipid
# PMC10906455_bioc.json,no predictions_lipid
# PMC10975297_bioc.json,no predictions_lipid
# PMC10637636_bioc.json,no predictions_lipid
# PMC10986626_bioc.json,no predictions_lipid
# PMC9370832_bioc.json,no predictions_lipid
# PMC9537637_bioc.json,no predictions_lipid
# PMC9604491_bioc.json,no predictions_lipid
# PMC10942300_bioc.json,no predictions_lipid
# PMC10584760_bioc.json,no predictions_lipid
# PMC11088129_bioc.json,no predictions_lipid
# PMC10500013_bioc.json,no predictions_lipid
# PMC10328534_bioc.json,no predictions_lipid
# PMC11142111_bioc.json,no predictions_lipid
# PMC11124142_bioc.json,no predictions_lipid
# PMC10672761_bioc.json,no predictions_lipid
# PMC9259596_bioc.json,no predictions_lipid
# PMC10924370_bioc.json,no predictions_lipid
# PMC10889185_bioc.json,no predictions_lipid
# PMC3472284_bioc.json,no predictions_lipid
# PMC10850136_bioc.json,no predictions_lipid
# PMC11116732_bioc.json,no predictions_lipid
# PMC9032865_bioc.json,no predictions_lipid
# PMC10603251_bioc.json,no predictions_lipid
# PMC10531708_bioc.json,no predictions_lipid
# PMC10809459_bioc.json,no predictions_lipid
# PMC9254412_bioc.json,no predictions_lipid
# PMC10874277_bioc.json,no predictions_lipid
# PMC10959946_bioc.json,no predictions_lipid
# PMC10531869_bioc.json,no predictions_lipid
# PMC9630270_bioc.json,no predictions_lipid
# PMC9099135_bioc.json,no predictions_lipid
# PMC9602909_bioc.json,no predictions_lipid
# PMC9286512_bioc.json,no predictions_lipid
# PMC10344703_bioc.json,no predictions_lipid
# PMC10877772_bioc.json,no predictions_lipid
# PMC10436642_bioc.json,no predictions_lipid
# PMC10932002_bioc.json,no predictions_lipid
# PMC9227925_bioc.json,no predictions_lipid
# PMC9570185_bioc.json,no predictions_lipid
# PMC11157816_bioc.json,no predictions_lipid
# PMC10509278_bioc.json,no predictions_lipid
# PMC9357171_bioc.json,no predictions_lipid
# PMC9693300_bioc.json,no predictions_lipid
# PMC10875595_bioc.json,no predictions_lipid
# PMC9598902_bioc.json,no predictions_lipid
# PMC8968719_bioc.json,no predictions_lipid
# PMC9066074_bioc.json,no predictions_lipid
# PMC9048792_bioc.json,no predictions_lipid
# PMC9633664_bioc.json,no predictions_lipid
# PMC10420921_bioc.json,no predictions_lipid
# PMC11070440_bioc.json,no predictions_lipid
# PMC9389305_bioc.json,no predictions_lipid
# PMC10688227_bioc.json,no predictions_lipid
# PMC10285285_bioc.json,no predictions_lipid
# PMC10494463_bioc.json,no predictions_lipid
# PMC10493471_bioc.json,no predictions_lipid
# PMC9586542_bioc.json,no predictions_lipid
# PMC9387699_bioc.json,no predictions_lipid
# PMC9456000_bioc.json,no predictions_lipid
# PMC11062907_bioc.json,no predictions_lipid
# PMC9113294_bioc.json,no predictions_lipid
# PMC9250719_bioc.json,no predictions_lipid
# PMC10987653_bioc.json,no predictions_lipid
# PMC10518349_bioc.json,no predictions_lipid
# PMC9072365_bioc.json,no predictions_lipid
# PMC10628503_bioc.json,no predictions_lipid
# PMC9316559_bioc.json,no predictions_lipid
# PMC9031822_bioc.json,no predictions_lipid
# PMC9038205_bioc.json,no predictions_lipid
# PMC10483287_bioc.json,no predictions_lipid
# PMC10543729_bioc.json,no predictions_lipid
# PMC8999923_bioc.json,no predictions_lipid
# PMC9685920_bioc.json,no predictions_lipid
# PMC10949529_bioc.json,no predictions_lipid
# PMC10503074_bioc.json,no predictions_lipid
# PMC10631159_bioc.json,no predictions_lipid
# PMC10579595_bioc.json,no predictions_lipid
# PMC9146996_bioc.json,no predictions_lipid
# PMC10483359_bioc.json,no predictions_lipid
# PMC11072846_bioc.json,no predictions_lipid
# PMC9032135_bioc.json,no predictions_lipid
# PMC10954550_bioc.json,no predictions_lipid
# PMC9523597_bioc.json,no predictions_lipid
# PMC10730992_bioc.json,no predictions_lipid
# PMC11143246_bioc.json,no predictions_lipid
# PMC9026925_bioc.json,no predictions_lipid
# PMC9696831_bioc.json,no predictions_lipid
# PMC9706947_bioc.json,no predictions_lipid
# PMC10618339_bioc.json,no predictions_lipid
# PMC10526550_bioc.json,no predictions_lipid
# PMC10780320_bioc.json,no predictions_lipid
# PMC10821107_bioc.json,no predictions_lipid
# PMC11148747_bioc.json,no predictions_lipid
# PMC10855791_bioc.json,no predictions_lipid
# PMC10470789_bioc.json,no predictions_lipid
# PMC9686702_bioc.json,no predictions_lipid
# PMC10725732_bioc.json,no predictions_lipid
# PMC10690232_bioc.json,no predictions_lipid
# PMC10881432_bioc.json,no predictions_lipid
# PMC10968317_bioc.json,no predictions_lipid
# PMC9024486_bioc.json,no predictions_lipid
# PMC9273185_bioc.json,no predictions_lipid
# PMC10571806_bioc.json,no predictions_lipid
# PMC11022805_bioc.json,no predictions_lipid
# PMC9197986_bioc.json,no predictions_lipid
# PMC10500075_bioc.json,no predictions_lipid
# PMC10977987_bioc.json,no predictions_lipid
# PMC10789383_bioc.json,no predictions_lipid
# PMC11024852_bioc.json,no predictions_lipid
# PMC10542644_bioc.json,no predictions_lipid
# PMC10532109_bioc.json,no predictions_lipid
# PMC10900781_bioc.json,no predictions_lipid
# PMC10375237_bioc.json,no predictions_lipid
# PMC10892910_bioc.json,no predictions_lipid
# PMC9525900_bioc.json,no predictions_lipid
# PMC11102634_bioc.json,no predictions_lipid
# PMC10369057_bioc.json,no predictions_lipid
# PMC10384603_bioc.json,no predictions_lipid
# PMC9479211_bioc.json,no predictions_lipid
# PMC9073783_bioc.json,no predictions_lipid
# PMC10921739_bioc.json,no predictions_lipid
# PMC9771980_bioc.json,no predictions_lipid
# PMC10807351_bioc.json,no predictions_lipid
# PMC11153016_bioc.json,no predictions_lipid
# PMC9486077_bioc.json,no predictions_lipid
# PMC9381039_bioc.json,no predictions_lipid
# PMC9326017_bioc.json,no predictions_lipid
# PMC10543316_bioc.json,no predictions_lipid
# PMC9264370_bioc.json,no predictions_lipid
# PMC11117475_bioc.json,no predictions_lipid
# PMC9635512_bioc.json,no predictions_lipid
# PMC8915990_bioc.json,no predictions_lipid
# PMC10772297_bioc.json,no predictions_lipid
# PMC10559927_bioc.json,no predictions_lipid
# PMC10381967_bioc.json,no predictions_lipid
# PMC10529749_bioc.json,no predictions_lipid
# PMC10755054_bioc.json,no predictions_lipid
# PMC10470028_bioc.json,no predictions_lipid
# PMC9220006_bioc.json,no predictions_lipid
# PMC10995404_bioc.json,no predictions_lipid
# PMC11095469_bioc.json,no predictions_lipid
# PMC9157458_bioc.json,no predictions_lipid
# PMC9547905_bioc.json,no predictions_lipid
# PMC11034944_bioc.json,no predictions_lipid
# PMC9047374_bioc.json,no predictions_lipid
# PMC10693150_bioc.json,no predictions_lipid
# PMC9613632_bioc.json,no predictions_lipid
# PMC9671920_bioc.json,no predictions_lipid
# PMC11148129_bioc.json,no predictions_lipid
# PMC10941554_bioc.json,no predictions_lipid
# PMC9569788_bioc.json,no predictions_lipid
# PMC10363632_bioc.json,no predictions_lipid
# PMC10413450_bioc.json,no predictions_lipid
# PMC9633531_bioc.json,no predictions_lipid
# PMC9287994_bioc.json,no predictions_lipid
# PMC10359364_bioc.json,no predictions_lipid
# PMC10973045_bioc.json,no predictions_lipid
# PMC9513222_bioc.json,no predictions_lipid
# PMC10410513_bioc.json,no predictions_lipid
# PMC10338713_bioc.json,no predictions_lipid
# PMC10536214_bioc.json,no predictions_lipid
# PMC9615529_bioc.json,no predictions_lipid
# PMC9002757_bioc.json,no predictions_lipid
# have predictions_lipid: 449, no predictions_lipid: 612

# %%
df_dict_only_lipid.keys()
df_dict_only_lipid['PMC10916870_bioc.json']['predictions_lipid']
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 509    None
# 510    None
# 511    None
# 512    None
# 513    None
# Name: predictions_lipid, Length: 514, dtype: object

# %%
#lipid and disease
import os
import torch
from transformers import AutoConfig, AutoTokenizer, AutoModelForTokenClassification
import pickle
import pandas as pd

def load_model_and_tokenizer(model_dir,device):
    # 加载配置文件、分词器和模型
    config = AutoConfig.from_pretrained(model_dir)
    tokenizer = AutoTokenizer.from_pretrained(model_dir)
    model = AutoModelForTokenClassification.from_pretrained(model_dir)
    
    model.to(device)
    model.eval()

    return config, tokenizer, model

def predict(text, tokenizer, model, label_map, device):
    # 将输入文本分词
    text_split = text.split()
    inputs = tokenizer(text_split, return_tensors="pt", truncation=True, is_split_into_words=True, max_length=512, add_special_tokens=False)
    input_ids = inputs["input_ids"].to(device)
    attention_mask = inputs["attention_mask"].to(device)

    # 使用模型进行预测
    with torch.no_grad():
        outputs = model(input_ids, attention_mask=attention_mask)
        
        # 兼容不同版本的transformers库
        if isinstance(outputs, tuple):
            logits = outputs[0]
        else:
            logits = outputs.logits

    # 获取预测结果
    predictions = torch.argmax(logits, dim=2)
    
    predictions = predictions.cpu().detach().numpy()  #gpu中的torch.tensor,需要先把它放进cpu才可以转化
    print(predictions)

    # 将预测结果转换为标签
    # example = "This is a tokenization example"
    txt_label_index_list = []
    #BatchEncoding.word_ids returns a list mapping words to tokens
    for w_idx in set(inputs.word_ids()):
        start, _ = inputs.word_to_tokens(w_idx)  #BatchEncoding.word_to_tokens tells us which and how many tokens are used for the specific word
        txt_label_index_list.append(start)         # we add +1 because you wanted to start with 1 and not with 0
    txt_predictions  = [predictions[0][index] for index in txt_label_index_list]
    return text_split,txt_predictions


# path_ = '/home/data/t200404/bioinfo/P_subject/NLP/biobert/datasets/for_recognize/download_paper_and_use_Auto-CORPus_deal_paper/deal/extract_result/'
# with open(path_ + 'df_dict_lipid_and_disease_4_combine_lipid_disease_ture_combine_2.pkl','rb') as f:
    # df_dict = pickle.load(f)

model_name = '4_combine_lipid_disease_ture_combine_3'
model_dir = "/home/data/t200404/bioinfo/P_subject/NLP/biobert/biobertModelWarehouse/model_from_trained/NER/"  # 替换为你模型的保存路径
model_dir = model_dir + model_name + "/"
config, tokenizer, model = load_model_and_tokenizer(model_dir,device = 'cuda')

label_map = config.id2label

# PMC_bioc_name = 'PMC11130959_bioc.json'
# dict_keys_list = list(df_dict.keys())
# start_index = dict_keys_list.index(PMC_bioc_name)
# for PMC_bioc_name in dict_keys_list[start_index:]:    
# save_batch = 10
# index_ = 0
# for PMC_bioc_name in dict_keys_list:    

#     if 'predictions_lipid' in df_dict[PMC_bioc_name].columns:
#         continue
#     else:
#         print(PMC_bioc_name)
#         results = df_dict[PMC_bioc_name]['sentence'].apply(
#             lambda x: predict(x, tokenizer, model, label_map, device='cuda')
#         )
#         df_dict[PMC_bioc_name]['text_split'], df_dict[PMC_bioc_name]['txt_predictions'] = zip(*results)
#         index_ += 1
#         if index_ % save_batch == 0:
#             with open(path_+ f'df_dict_lipid_and_disease_{model_name}'+'_word2label'+'.pkl','wb') as f:
#                 pickle.dump(df_dict, f)

# %%
x= '''Thus, changes in plasma S1P d16:1 levels, plasma Cer d18:1 levels, plasma MonCer d18:1 levels or plasma LacCer (d18:1/16:0) levels were inferred to be disease-induced changes in Alzheimer's disease or DLB'''
text_, pred_label = predict(x, tokenizer, model, label_map, device='cuda')
df_ = pd.DataFrame({'text': text_, 'pred_label': pred_label})
df_
